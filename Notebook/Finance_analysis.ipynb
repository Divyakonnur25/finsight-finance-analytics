# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('customers.csv')
df2=pd.read_csv('finance_transactions.csv')

# %%
display(df1.head())
# Out:
#   customer_id fisrt_name second_name  gender date_of_birth        city  \
# 0      C00001      Karan      Chopra    Male    09-10-1982     Kolkata
# 1      C00002     Ishaan       Patel    Male    07-10-1983  Chandigarh
# 2      C00003    Krishna       Patel    Male    27-11-1989   Hyderabad
# 3      C00004       Amit       Verma    Male    13-08-1970     Lucknow
# 4      C00005    Reyansh        Jain  Female    07-02-1977   Ahmedabad
#
#            state  occupation customer_segment  annual_income   join_date
# 0    West Bengal     Retired              SME      988416.79  15-04-2021
# 1     Chandigarh    Salaried          Premium      457149.28  06-04-2022
# 2      Telangana     Retired           Retail      378907.24  06-03-2026
# 3  Uttar Pradesh    Salaried           Retail      299085.16  16-07-2021
# 4        Gujarat  Freelancer              SME      775436.07  23-02-2023

# %%
display(df2.head())
# Out:
#   transaction_id transaction_date account_id customer_id transaction_type  \
# 0      T00000001       21-02-2025    A001795      C00629       Investment
# 1      T00000002       28-01-2023    A004859      C02038         Transfer
# 2      T00000003       25-06-2024    A003081      C00652         Transfer
# 3      T00000004       20-02-2025    A004122      C01357       Withdrawal
# 4      T00000005       06-08-2024    A004150      C02547          Deposit
#
#           channel merchant_category    amount  fee_amount  tax_amount  \
# 0      Mobile App     Food Delivery  24721.24      123.61       22.25
# 1             UPI         Groceries  18711.77       93.56       16.84
# 2     Net Banking         Groceries  45865.90        0.00        0.00
# 3      Auto Debit            Salary   4310.91         NaN        0.78
# 4          Branch          Shopping  11646.45        0.00        0.00
#
#   currency transaction_status is_fraud  risk_score   reference_no
# ...

# %%
df1.isnull().sum()
# Out:
# customer_id         0
# fisrt_name          0
# second_name         0
# gender              0
# date_of_birth       0
# city                0
# state               0
# occupation          0
# customer_segment    0
# annual_income       0
# join_date           0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# transaction_id         0
# transaction_date       0
# account_id             0
# customer_id            0
# transaction_type       0
# channel                0
# merchant_category      0
# amount                 0
# fee_amount            24
# tax_amount             0
# currency               0
# transaction_status     0
# is_fraud               0
# risk_score             0
# reference_no           0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2.duplicated().sum()
# Out:
# np.int64(68)

# %%
df2.duplicated(subset=['transaction_id']).sum()
# Out:
# np.int64(69)

# %%
df1.shape
# Out:
# (5000, 11)

# %%
df2.shape
# Out:
# (50069, 15)

# %%
target=df2['transaction_id']
duplicates=df2[df2.duplicated(subset=['transaction_id'], keep=False)]
print(duplicates)
# Out:
#       transaction_id transaction_date account_id customer_id transaction_type  \
# 8          T00000009       24-09-2024    A006977      C01463         Transfer
# 9          T00000009       24-09-2024    A006977      C01463         Transfer
# 14         T00000014       10-08-2024    A004138      C00960         Loan EMI
# 15         T00000014       10-08-2024    A004138      C00960         Loan EMI
# 66         T00000065       26-02-2023    A006060      C00103          Deposit
# ...              ...              ...        ...         ...              ...
# 50064      T00049879       01-09-2024    A006793      C02066         Transfer
# 50065      T00049880       27-06-2025    A003754      C01053         Loan EMI
# 50066      T00049881       02-08-2024    A003657      C02434         Loan EMI
# 50067      T00049882       13-11-2023    A003840      C03287         Transfer
# 50068      T00049883       25-02-2025    A007128      C03308     Bill Payment
#
# ...

# %%
df2.drop_duplicates(subset=['transaction_id'], keep='first', inplace=True)

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2.shape
# Out:
# (50000, 15)

# %%
df2.isnull().sum()
# Out:
# transaction_id         0
# transaction_date       0
# account_id             0
# customer_id            0
# transaction_type       0
# channel                0
# merchant_category      0
# amount                 0
# fee_amount            24
# tax_amount             0
# currency               0
# transaction_status     0
# is_fraud               0
# risk_score             0
# reference_no           0
# dtype: int64

# %%
mean_value=df2['fee_amount'].mean().round(2)
print(mean_value)
# Out:
# 14.52

# %%
df2['fee_amount']=df2['fee_amount'].fillna(mean_value)

# %%
df2.isnull().sum()
# Out:
# transaction_id        0
# transaction_date      0
# account_id            0
# customer_id           0
# transaction_type      0
# channel               0
# merchant_category     0
# amount                0
# fee_amount            0
# tax_amount            0
# currency              0
# transaction_status    0
# is_fraud              0
# risk_score            0
# reference_no          0
# dtype: int64

# %%
print(df2['fee_amount'].isnull().sum())
# Out:
# 0

# %%
df2['channel']
# Out:
# 0            Mobile App
# 1                   UPI
# 2           Net Banking
# 3            Auto Debit
# 4                Branch
#               ...
# 49999        Auto Debit
# 50000        Mobile App
# 50001               UPI
# 50002        Mobile App
# 50003            Branch
# Name: channel, Length: 50000, dtype: str

# %%
df2.dtypes
# Out:
# transaction_id            str
# transaction_date          str
# account_id                str
# customer_id               str
# transaction_type          str
# channel                   str
# merchant_category         str
# amount                float64
# fee_amount            float64
# tax_amount            float64
# currency                  str
# transaction_status        str
# is_fraud                  str
# risk_score              int64
# reference_no              str
# dtype: object

# %%
df2['transaction_date']=pd.to_datetime(df2['transaction_date'] )
# Out:
# C:\Users\kk\AppData\Local\Temp\ipykernel_17412\4179813370.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df2['transaction_date']=pd.to_datetime(df2['transaction_date'] )

# %%
df1.dtypes
# Out:
# customer_id             str
# fisrt_name              str
# second_name             str
# gender                  str
# date_of_birth           str
# city                    str
# state                   str
# occupation              str
# customer_segment        str
# annual_income       float64
# join_date               str
# dtype: object

# %%
df1['date_of_birth'] = pd.to_datetime(
    df1['date_of_birth'],
    format='%d-%m-%Y'
)

df1['join_date'] = pd.to_datetime(
    df1['join_date'],
    format='%d-%m-%Y'
)

# %%
df1.dtypes
# Out:
# customer_id                    str
# fisrt_name                     str
# second_name                    str
# gender                         str
# date_of_birth       datetime64[us]
# city                           str
# state                          str
# occupation                     str
# customer_segment               str
# annual_income              float64
# join_date           datetime64[us]
# dtype: object

# %%
df2.dtypes
# Out:
# transaction_id                   str
# transaction_date      datetime64[us]
# account_id                       str
# customer_id                      str
# transaction_type                 str
# channel                          str
# merchant_category                str
# amount                       float64
# fee_amount                   float64
# tax_amount                   float64
# currency                         str
# transaction_status               str
# is_fraud                         str
# risk_score                     int64
# reference_no                     str
# dtype: object

# %%
df2.head()
# Out:
#   transaction_id transaction_date account_id customer_id transaction_type  \
# 0      T00000001       2025-02-21    A001795      C00629       Investment
# 1      T00000002       2023-01-28    A004859      C02038         Transfer
# 2      T00000003       2024-06-25    A003081      C00652         Transfer
# 3      T00000004       2025-02-20    A004122      C01357       Withdrawal
# 4      T00000005       2024-08-06    A004150      C02547          Deposit
#
#           channel merchant_category    amount  fee_amount  tax_amount  \
# 0      Mobile App     Food Delivery  24721.24      123.61       22.25
# 1             UPI         Groceries  18711.77       93.56       16.84
# 2     Net Banking         Groceries  45865.90        0.00        0.00
# 3      Auto Debit            Salary   4310.91       14.52        0.78
# 4          Branch          Shopping  11646.45        0.00        0.00
#
#   currency transaction_status is_fraud  risk_score   reference_no
# ...

# %%
df2['currency'].unique()
# Out:
# <ArrowStringArray>
# ['INR', 'inr', 'inR']
# Length: 3, dtype: str

# %%
df2['currency']=df2['currency'].str.upper()

# %%
df2['transaction_type'].unique()
# Out:
# <ArrowStringArray>
# [     'Investment',        'Transfer',      'Withdrawal',         'Deposit',
#         'Loan EMI', 'Interest Credit',    'Card Payment',    'Bill Payment',
#       'Fee Charge',          'Refund']
# Length: 10, dtype: str

# %%
df2['merchant_category'].unique()
# Out:
# <ArrowStringArray>
# ['Food Delivery',     'Groceries',        'Salary',      'Shopping',
#      'Insurance',     'Education',          'Rent',    'Healthcare',
#   'Bank Charges',          'Fuel',        'Travel',     'Utilities',
#  'Entertainment',   'Mutual Fund']
# Length: 14, dtype: str

# %%
df2['is_fraud'].unique()
# Out:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
